# %% [markdown]
# <a href="https://colab.research.google.com/github/arielbiotechcr/teaching-stats/blob/main/try_r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This is a try colab
print('Hello World')
# Out:
# [1] "Hello World"
